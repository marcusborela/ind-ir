# %% [markdown]
# # Testes básicos de acesso e parsing

# %%
import requests

api_url = "https://jsonplaceholder.typicode.com/todos/1"
response = requests.get(api_url)
response.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
api_url = "https://pesquisa.apps.tcu.gov.br/rest/publico/base/jurisprudencia-selecionada/documentosResumidos?termo=t%C3%A9cnica%20e%20pre%C3%A7o&filtro=&ordenacao=score%20desc,%20COLEGIADO%20asc,%20ANOACORDAO%20desc,%20NUMACORDAO%20desc&quantidade=20&inicio=0&sinonimos=true"
response = requests.get(api_url)
response.json()
# Out:
# {'quantidadeEncontrada': 187,
#  'inicio': 0,
#  'documentos': [{'KEY': 'JURISPRUDENCIA-SELECIONADA-34240',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20170512',
#    'NUMACORDAO': '1782',
#    'ANOACORDAO': '2004',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Parcelamento do objeto',
#    'SUBTEMA': 'Obrigatoriedade',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'SÚMULA TCU 247: É obrigatória a admissão da adjudicação por item e não por <em>preço</em> global, nos editais das licitações para a contratação de obras, serviços, compras e alienações, cujo objeto seja divisível, desde que não haja prejuízo para o conjunto ou complexo ou perda de economia de escala, tendo em vista o objetivo de propiciar a ampla participação de licitantes que, embora não dispondo de capacidade para a execução, fornecimento ou aquisição da totalidade do objeto, possam fazê-lo com relação a itens ou unidades autônomas, devendo as exigências de habilitação adequar-se a essa divisibilidade.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '10/11/2004',
#    'AUTORTESE': 'MARCOS VINICIOS VILAÇA',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Súmula, Economia de escala, Viabilidade <em>técnica</em>, Viabilidade econômica, Acréscimo, Licitação por item, Competitividade',
#    'PARADIGMATICO': 'Este enunciado foi classificado como paradigmático por tratar-se de súmula',
#    'SCORE': 16539.848},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20956',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20170511',
#    'NUMACORDAO': '624',
#    'ANOACORDAO': '2010',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Obras e serviços de engenharia',
#    'SUBTEMA': 'BDI',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'SÚMULA TCU 253: Comprovada a inviabilidade <em>técnico</em>-econômica de parcelamento do objeto da licitação, nos termos da legislação em vigor, os itens de fornecimento de materiais e equipamentos de natureza específica que possam ser fornecidos por empresas com especialidades próprias e diversas e que representem percentual significativo do <em>preço</em> global da obra devem apresentar incidência de taxa de Bonificação e Despesas Indiretas - BDI reduzida em relação à taxa aplicável aos demais itens.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '31/03/2010',
#    'AUTORTESE': 'AUGUSTO NARDES',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Parcelamento do objeto, Inviabilidade, Material de construção, Equipamentos, Súmula',
#    'PARADIGMATICO': 'Este enunciado foi classificado como paradigmático por tratar-se de súmula',
#    'SCORE': 6567.644},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-68513',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20190319',
#    'NUMACORDAO': '276',
#    'ANOACORDAO': '2019',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Direito de preferência',
#    'SUBTEMA': 'Produto controlado',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Quando os produtos controlados nacionais tratados pelo Decreto 3.665/2000, pela Portaria Normativa-MD 620/2006 ou pela Portaria-DLOG/EB/MD 18/2006 tiverem seus <em>preços</em> 25% maiores do que seus similares estrangeiros, considerados todos os custos de importação, não deverão ser adquiridos pela Administração Pública, em observância ao art. 3°, § 8°, da Lei 8.666/1993, aplicável às aquisições de produtos controlados. Nesse caso, deve ser adquirido o similar estrangeiro, desde que atendidos os critérios <em>técnicos</em> mínimos de admissibilidade.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '13/02/2019',
#    'AUTORTESE': 'VITAL DO RÊGO',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Limite máximo, Produto nacional, Produto estrangeiro, Margem de preferência, Consulta, <em>Preço</em>',
#    'PARADIGMATICO': 'Este enunciado foi classificado como paradigmático por tratar-se de resposta a consulta',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=61194491">Informativo de Licitações e Contratos nº 363 de 19/03/2019</a>',
#     '<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=61136651">Boletim de Jurisprudência nº 253 de 11/03/2019</a>'],
#    'SCORE': 2942.87},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-51881',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20180302',
#    'NUMACORDAO': '205',
#    'ANOACORDAO': '2018',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Contrato Administrativo',
#    'TEMA': 'Terceirização',
#    'SUBTEMA': 'Reserva <em>técnica</em>',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'A inclusão do item "reserva <em>técnica"</em> nas planilhas de custos e formação de <em>preços</em> dos contratos com empresas prestadoras de serviços terceirizados somente é admitida se houver justificativa prévia e expressa dos custos correspondentes que serão cobertos por esse item.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '07/02/2018',
#    'AUTORTESE': 'AROLDO CEDRAZ',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa',
#    'PARADIGMATICO': 'Este enunciado foi classificado como paradigmático de acordo com avaliação da equipe da diretoria de jurisprudência do TCU',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=58894231">Boletim de Jurisprudência nº 206 de 05/03/2018</a>'],
#    'SCORE': 2257.276},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-39213',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20170511',
#    'NUMACORDAO': '1399',
#    'ANOACORDAO': '2010',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Obras e serviços de engenharia',
#    'SUBTEMA': 'Orçamento estimativo',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'É obrigação do Exército, nos orçamentos para obras em regime de cooperação com órgão federal, em que seja utilizada metodologia diferenciada, observar os seguintes procedimentos: a) adoção de total transparência na orçamentação, apropriação e uso dos recursos provenientes da depreciação dos equipamentos de engenharia utilizados; b) registro, a título de depreciação, apenas daquela prevista para os equipamentos a serem utilizados na própria obra; c) especificação e quantificação, no Plano de Trabalho, da depreciação registrada no orçamento; d) justificação da adoção de índices de produtividade inferiores ao máximo, conforme faixa de variação prevista na metodologia; e) utilização de produtividades tradicionais no caso de serviços terceirizados; f) orçamento detalhado das atividades de mobilização, desmobilização, canteiro e acampamento e seu registro como custo direto; g) devolução dos saldos financeiros remanescentes, inclusive os provenientes das receitas obtidas nas aplicações financeiras realizadas, à entidade ou órgão repassador dos recursos. Quando a aplicação do procedimento diferenciado resultar em <em>preço</em> unitário ou <em>preço</em> global superior ao que seria obtido por meio da utilização do método tradicional, o Exército deverá apresentar relatório <em>técnico</em> circunstanciado, elaborado por profissional habilitado e aprovado pela autoridade competente.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '16/06/2010',
#    'AUTORTESE': 'MARCOS BEMQUERER',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Metodologia, Exército, Consulta, Obrigatoriedade',
#    'PARADIGMATICO': 'Este enunciado foi classificado como paradigmático por tratar-se de resposta a consulta',
#    'SCORE': 1747.2755},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-21229',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '525',
#    'ANOACORDAO': '2012',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'O estabelecimento de critério de pontuação <em>técnica,</em> em licitação do tipo <em>técnica</em> e <em>preço,</em> que valoriza excessivamente determinado quesito, em detrimento do <em>preço,</em> restringe o caráter competitivo do certame e compromete a obtenção da proposta mais vantajosa para a Administração.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '07/03/2012',
#    'AUTORTESE': 'WEDER DE OLIVEIRA',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Princípio da proporcionalidade, Proposta de <em>preço</em>',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982442">Informativo de Licitações e Contratos nº 96</a>'],
#    'SCORE': 246.98103},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-21285',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160921',
#    'NUMACORDAO': '2353',
#    'ANOACORDAO': '2011',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Critério',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Em licitação do tipo <em>técnica</em> e <em>preço,</em> é admissível a exigência de nota mínima para valorização da proposta, no que se refere aos quesitos de avaliação da proposta <em>técnica.</em>',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '31/08/2011',
#    'AUTORTESE': 'RAIMUNDO CARREIRO',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Nota mínima',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982318">Informativo de Licitações e Contratos nº 78</a>'],
#    'SCORE': 198.5696},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-17125',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160826',
#    'NUMACORDAO': '1977',
#    'ANOACORDAO': '2013',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Contrato Administrativo',
#    'TEMA': 'Empreitada por <em>preço</em> global',
#    'SUBTEMA': 'Quantificação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'A utilização da empreitada por <em>preço</em> global para objetos com imprecisão intrínseca de quantitativos deve ser justificada no processo, em termos <em>técnicos,</em> econômicos ou outros devidamente motivados.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '31/07/2013',
#    'AUTORTESE': 'VALMIR CAMPELO',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa, Fundamentação <em>técnica</em>, Imprecisão, Economicidade',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982342">Informativo de Licitações e Contratos nº 162</a>'],
#    'SCORE': 148.66994},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-18324',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20161003',
#    'NUMACORDAO': '1288',
#    'ANOACORDAO': '2011',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Orçamento estimativo',
#    'SUBTEMA': '<em>Preço</em>',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Limitação das propostas de <em>preço</em> ao orçamento de referência da licitação é aplicável também às licitações que utilizem o tipo <em>técnica</em> e <em>preço.</em>',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '18/05/2011',
#    'AUTORTESE': 'JOSÉ MUCIO MONTEIRO',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': '<em>Preço</em> máximo, Proposta de preço, Licitação de <em>técnica</em> e <em>preço</em>',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982321">Informativo de Licitações e Contratos nº 63</a>'],
#    'SCORE': 130.49156},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-21159',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160921',
#    'NUMACORDAO': '2909',
#    'ANOACORDAO': '2012',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'A adoção, em licitação do tipo <em>técnica</em> e <em>preço,</em> de peso excessivamente elevado para a pontuação <em>técnica</em> em relação à de <em>preço,</em> sem justificativa plausível, e de critérios subjetivos de julgamento das propostas contraria o disposto nos arts. 3º, 40, inciso VII, 44, § 1º, e 45, da Lei 8.666/1993.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '24/10/2012',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa, Proposta, Valoração, Critério, Julgamento',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982519">Informativo de Licitações e Contratos nº 129</a>'],
#    'SCORE': 130.30167},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20870',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '546',
#    'ANOACORDAO': '2011',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Nas licitações do tipo <em>técnica</em> e <em>preço,</em> a atribuição de pontuação distinta para <em>técnica</em> e <em>preço</em> demanda justificativa.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '02/03/2011',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa, Proposta de <em>preço</em>, Critério, Proposta <em>técnica</em>',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982343">Informativo de Licitações e Contratos nº 53</a>'],
#    'SCORE': 127.013535},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20969',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '1041',
#    'ANOACORDAO': '2010',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'É necessário justificar os pesos das notas de ponderação de <em>técnica</em> e <em>preço,</em> em especial quando o peso do critério <em>preço</em> ficar abaixo do <em>técnico.</em>',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '12/05/2010',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa, Proposta de <em>preço</em>, Critério, Proposta <em>técnica</em>',
#    'SCORE': 126.54108},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20970',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '1597',
#    'ANOACORDAO': '2010',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Em licitação do tipo <em>técnica</em> e <em>preço,</em> é necessária a ponderação entre os pesos dos índices <em>técnico</em> e de <em>preço,</em> explicitando no processo a fundamentação para os pesos atribuídos.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '07/07/2010',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa, Proposta de <em>preço</em>, Critério, Proposta <em>técnica</em>',
#    'SCORE': 126.2808},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20971',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '327',
#    'ANOACORDAO': '2010',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Em licitações do tipo <em>técnica</em> e <em>preço,</em> é indevido atribuir peso desproporcional ao critério da <em>técnica</em> de forma a tornar irrisório o fator <em>preço</em> no julgamento das propostas.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '03/03/2010',
#    'AUTORTESE': 'BENJAMIN ZYMLER',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Princípio da proporcionalidade, Proposta de <em>preço</em>',
#    'SCORE': 124.236755},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20869',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '210',
#    'ANOACORDAO': '2011',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Eventual desproporção na pontuação atribuída aos critérios de <em>técnica</em> e de <em>preço</em> deve ser justificada.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '02/02/2011',
#    'AUTORTESE': 'AUGUSTO NARDES',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Justificativa, Proposta de <em>preço</em>, Critério, Proposta <em>técnica</em>',
#    'PUBLICACAOAPRESENTACAO': ['<a href="http://contas.tcu.gov.br/sisdoc/ObterDocumentoSisdoc?codPapelTramitavel=54982466">Informativo de Licitações e Contratos nº 49</a>'],
#    'SCORE': 124.157005},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-34126',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20170216',
#    'NUMACORDAO': '667',
#    'ANOACORDAO': '2005',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'O peso dos fatores de avaliação da proposta <em>técnica</em> devem ser pertinentes com a representatividade de cada fator para o serviço licitado. A ponderação da proposta <em>técnica</em> e do <em>preço</em> deve pautar-se na complexidade dos serviços a serem contratados, aplicando pesos consentâneos com esse aspecto.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '25/05/2005',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Complexidade, Proposta de <em>preço</em>, Serviços',
#    'SCORE': 123.359314},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-31601',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20170130',
#    'NUMACORDAO': '503',
#    'ANOACORDAO': '2008',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'A desproporcionalidade da <em>técnica</em> em relação ao <em>preço</em> pode acarretar a seleção de proposta economicamente desvantajosa, baseada em vantagem <em>técnica</em> pouco significativa.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '26/03/2008',
#    'AUTORTESE': 'AROLDO CEDRAZ',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Compatibilidade, Proposta de <em>preço</em>, Critério, Julgamento',
#    'SCORE': 122.995384},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-20871',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '309',
#    'ANOACORDAO': '2011',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'O desbalanceamento entre critérios de <em>técnica</em> e <em>preço</em> torna possível o direcionamento da licitação, restringindo a competitividade e, consequentemente, o número de propostas apresentadas.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '09/02/2011',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Princípio da proporcionalidade, Proposta de <em>preço</em>',
#    'SCORE': 121.17514},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-21072',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20160920',
#    'NUMACORDAO': '2017',
#    'ANOACORDAO': '2009',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'É indevida a excessiva valoração da proposta <em>técnica,</em> em detrimento da proposta de <em>preços,</em> sem amparo em justificativas <em>técnicas</em> suficientes que demonstrem a sua necessidade, uma vez que a adoção de critério desproporcional pode acarretar prejuízo à competitividade do certame e à obtenção da proposta mais vantajosa pela Administração.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '02/09/2009',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Princípio da proporcionalidade, Proposta de <em>preço</em>',
#    'SCORE': 120.134964},
#   {'KEY': 'JURISPRUDENCIA-SELECIONADA-34233',
#    'FAVORITO': False,
#    'DTATUALIZACAO': '20170214',
#    'NUMACORDAO': '1094',
#    'ANOACORDAO': '2004',
#    'COLEGIADO': 'Plenário',
#    'AREA': 'Licitação',
#    'TEMA': 'Licitação de <em>técnica</em> e <em>preço</em>',
#    'SUBTEMA': 'Ponderação',
#    'ASSUNTO': '',
#    'ENUNCIADO': 'Os fatores de avaliação das propostas <em>técnicas</em> e de <em>preços</em> devem ser proporcionais ao grau de complexidade dos serviços.',
#    'NUMSUMULA': '',
#    'DATASESSAOFORMATADA': '04/08/2004',
#    'AUTORTESE': 'AUGUSTO SHERMAN',
#    'FUNCAOAUTORTESE': 'RELATOR',
#    'INDEXACAO': 'Proposta <em>técnica</em>, Complexidade, Proposta de <em>preço</em>, Serviços',
#    'SCORE': 119.320915}],
#  'mensagemAlerta': None,
#  'facetasResumidas': None,
#  'facetas': {'campos': [{'nome': 'COPIAAREA',
#     'tipo': 'SIMPLES',
#     'itens': ['Contrato Administrativo',
#      20,
#      'Convênio',
#      3,
#      'Licitação',
#      161,
#      'Responsabilidade',
#      3],
#     'filhos': None},
#    {'nome': 'COPIATEMA',
#     'tipo': 'SIMPLES',
#     'itens': ['Aditivo',
#      2,
#      'Bens e serviços de informática',
#      2,
#      'Concedente',
#      1,
#      'Contrato administrativo',
#      1,
#      'Convênio',
#      2,
#      'Direito de preferência',
#      1,
#      'Edital de licitação',
#      2,
#      'Empreitada por preço global',
#      1,
#      'Empreitada por preço unitário',
#      1,
#      'Estudo de viabilidade',
#      2,
#      'Fiscalização',
#      2,
#      'Formalização',
#      1,
#      'Habilitação de licitante',
#      3,
#      'Inexigibilidade de licitação',
#      2,
#      'Julgamento',
#      2,
#      'Licitação de técnica e preço',
#      83,
#      'Obras e serviços de engenharia',
#      24,
#      'Orçamento estimativo',
#      8,
#      'Parcelamento do objeto',
#      4,
#      'Parentesco',
#      1,
#      'Plano de trabalho',
#      2,
#      'Pregão',
#      8,
#      'Pré-qualificação',
#      2,
#      'Projeto básico',
#      3,
#      'Proposta',
#      1,
#      'Qualificação técnica',
#      1,
#      'RDC',
#      7,
#      'Registro de preços',
#      5,
#      'Serviços contínuos',
#      6,
#      'Sobrepreço',
#      1,
#      'Superfaturamento',
#      4,
#      'Terceirização',
#      2],
#     'filhos': None},
#    {'nome': 'COPIASUBTEMA',
#     'tipo': 'SIMPLES',
#     'itens': ['Adesão à ata de registro de preços',
#      3,
#      'Aditivo',
#      1,
#      'Análise de custos',
#      2,
#      'Autos',
#      1,
#      'BDI',
#      3,
#      'Bens e serviços de informática',
#      1,
#      'Composição',
#      1,
#      'Concedente',
#      2,
#      'Contratação integrada',
#      3,
#      'Critério',
#      49,
#      'Detalhamento',
#      2,
#      'Elaboração',
#      3,
#      'Especificação técnica',
#      1,
#      'Exigência',
#      3,
#      'Experiência profissional',
#      2,
#      'Habilitação de licitante',
#      1,
#      'Lote (Licitação)',
#      1,
#      'Marca',
#      1,
#      'Metodologia',
#      4,
#      'Negociação',
#      1,
#      'Obras e serviços de engenharia',
#      3,
#      'Obrigação',
#      1,
#      'Obrigatoriedade',
#      4,
#      'Orçamento estimativo',
#      8,
#      'Pagamento',
#      1,
#      'Planejamento',
#      6,
#      'Ponderação',
#      29,
#      'Prazo',
#      2,
#      'Preço',
#      8,
#      'Princípio da vinculação ao instrumento convocatório',
#      1,
#      'Produto controlado',
#      1,
#      'Proposta técnica',
#      5,
#      'Quantificação',
#      1,
#      'Requisito',
#      8,
#      'Reserva técnica',
#      7,
#      'Rodovia',
#      3,
#      'Serviço de manutenção e reparos',
#      1,
#      'Serviço novo',
#      1,
#      'Serviços advocatícios',
#      1,
#      'Serviço técnico especializado',
#      2,
#      'Superfaturamento',
#      7,
#      'Vedação',
#      1,
#      'Vistoria',
#      1],
#     'filhos': None}],
#   'camposResumidos': [{'nome': 'COPIAAREA',
#     'tipo': 'SIMPLES',
#     'itens': ['Contrato Administrativo',
#      20,
#      'Convênio',
#      3,
#      'Licitação',
#      161,
#      'Responsabilidade',
#      3],
#     'filhos': None},
#    {'nome': 'COPIATEMA',
#     'tipo': 'SIMPLES',
#     'itens': ['Aditivo',
#      2,
#      'Bens e serviços de informática',
#      2,
#      'Concedente',
#      1,
#      'Contrato administrativo',
#      1,
#      'Convênio',
#      2,
#      'Direito de preferência',
#      1,
#      'Edital de licitação',
#      2,
#      'Empreitada por preço global',
#      1,
#      'Empreitada por preço unitário',
#      1,
#      'Estudo de viabilidade',
#      2],
#     'filhos': None},
#    {'nome': 'COPIASUBTEMA',
#     'tipo': 'SIMPLES',
#     'itens': ['Adesão à ata de registro de preços',
#      3,
#      'Aditivo',
#      1,
#      'Análise de custos',
#      2,
#      'Autos',
#      1,
#      'BDI',
#      3,
#      'Bens e serviços de informática',
#      1,
#      'Composição',
#      1,
#      'Concedente',
#      2,
#      'Contratação integrada',
#      3,
#      'Critério',
#      49],
#     'filhos': None}]},
#  'spell': None}

# %%
[int(doc['KEY'].split('-')[-1]) if doc['KEY'].startswith('JURISPRUDENCIA-SELECIONADA-') else 0 for doc in response.json()['documentos']]
# Out:
# [34240,
#  20956,
#  68513,
#  51881,
#  39213,
#  21229,
#  21285,
#  17125,
#  18324,
#  21159,
#  20870,
#  20969,
#  20970,
#  20971,
#  20869,
#  34126,
#  31601,
#  20871,
#  21072,
#  34233]

# %%
import urllib.parse

query = 'técnica e preço'
quoted_query = urllib.parse.quote(query)
query + ' --> ' + quoted_query
# Out:
# 'técnica e preço --> t%C3%A9cnica%20e%20pre%C3%A7o'

# %%
api_url = f"https://pesquisa.apps.tcu.gov.br/rest/publico/base/jurisprudencia-selecionada/documentosResumidos?termo={quoted_query}&filtro=&ordenacao=score%20desc,%20COLEGIADO%20asc,%20ANOACORDAO%20desc,%20NUMACORDAO%20desc&quantidade=20&inicio=0&sinonimos=true"
api_url
# Out:
# 'https://pesquisa.apps.tcu.gov.br/rest/publico/base/jurisprudencia-selecionada/documentosResumidos?termo=t%C3%A9cnica%20e%20pre%C3%A7o&filtro=&ordenacao=score%20desc,%20COLEGIADO%20asc,%20ANOACORDAO%20desc,%20NUMACORDAO%20desc&quantidade=20&inicio=0&sinonimos=true'

# %% [markdown]
# # Carga das queries e execução da busca

# %%
import pandas as pd

df_queries = pd.read_csv('../../data/juris_tcu/query.csv')
df_queries
# Out:
#       ID                                               TEXT      SOURCE
# 0      1                                    técnica e preço  search log
# 1      2                                     restos a pagar  search log
# 2      3                                 aditivo a contrato  search log
# 3      4                 adesão a ata de registro de preços  search log
# 4      5                      sobrepreço e superfaturamento  search log
# ..   ...                                                ...         ...
# 145  146  É possível a inclusão de serviços já previstos...         LLM
# 146  147  O princípio da legalidade estrita pode ser afa...         LLM
# 147  148  Quais fontes devem ser prioritárias na pesquis...         LLM
# 148  149  Devem ser aceitas nas contratações de software...         LLM
# 149  150  Qual é a regra geral para a contratação de ent...         LLM
#
# [150 rows x 3 columns]

# %%
result = {}
for id, query in list(df_queries[['ID', 'TEXT']].values):
    quoted_query = urllib.parse.quote(query)
    api_url = f"https://pesquisa.apps.tcu.gov.br/rest/publico/base/jurisprudencia-selecionada/documentosResumidos?termo={quoted_query}&filtro=&ordenacao=score%20desc,%20COLEGIADO%20asc,%20ANOACORDAO%20desc,%20NUMACORDAO%20desc&quantidade=20&inicio=0&sinonimos=true"
    print('Query', id, '-', query+  ':')
    response = requests.get(api_url)
    result[id] = [int(doc['KEY'].split('-')[-1]) if doc['KEY'].startswith('JURISPRUDENCIA-SELECIONADA-') else 0 for doc in response.json()['documentos']]
    print('\t', result[id])
# Out:
# Query 1 - técnica e preço:
# 	 [34240, 20956, 68513, 51881, 39213, 21229, 21285, 17125, 18324, 21159, 20870, 20969, 20970, 20971, 20869, 34126, 31601, 20871, 21072, 34233]
# Query 2 - restos a pagar:
# 	 [53678, 39200, 112346, 47053, 56445, 18430, 103476, 32869, 77959, 18105, 19084, 17289, 19340, 31437, 76612, 18432, 18452]
# Query 3 - aditivo a contrato:
# 	 [17089, 108415, 10089, 11611, 11612, 59295, 59296, 104455, 81314, 81554, 59318, 59317, 34116, 18416, 17816, 49716, 139160, 31084, 15197, 31120]
# Query 4 - adesão a ata de registro de preços:
# 	 [137717, 20949, 15092, 15372, 20839, 52912, 4230, 15178, 147727, 62306, 50537, 16895, 17195, 70413, 20860, 20841, 41295, 49694, 20840, 42169]
# Query 5 - sobrepreço e superfaturamento:
# 	 [17816, 148920, 23515, 20524, 17813, 16932, 21171, 32590, 21227, 100548, 77235, 21172, 86727, 9527, 18393, 20523, 53003, 16262, 21793, 22908]
# Query 6 - restrição a competitividade:
# 	 [34918, 18286, 17165, 17916, 13109, 18259, 25442, 14527, 16409, 17372, 23050, 59438, 17045, 104234, 16910, 22194, 18291, 34229, 8276, 34943]
# Query 7 - acréscimos e supressões:
# 	 [10089, 17089, 11611, 11612, 104455, 17022, 18001, 18020, 18936, 49135, 17068, 17204, 17205, 17209, 17206, 18014, 134594, 17207, 109711, 67219]
# Query 8 - obras e serviços de engenharia:
# 	 [18827, 20953, 20972, 20974, 20977, 189, 20956, 20896, 39215, 14809, 54843, 22191, 14829, 39212, 22173, 39213, 54815, 20915, 39214, 79794]
# Query 9 - fiscalizacao de contratos:
# 	 [40473, 34284, 86184, 15409, 91254, 53626, 53417, 18061, 28852, 19335, 32630, 18067, 18903, 16954, 18030, 32644, 16945, 43178, 18943, 15185]
# Query 10 - diarias e passagens:
# 	 [19614, 25478, 32385, 14250, 28521, 33681, 59656, 30893, 32381, 30891, 32379, 30290, 30086, 32384, 33649, 30107, 30310, 31684, 30371, 30890]
# Query 11 - bens e serviços comuns:
# 	 [8469, 39204, 98914, 98935, 34145, 33939, 40469, 18889, 18275, 17831, 18245, 33914, 18828, 18871, 33912, 44087, 33913, 34112, 17913, 17911]
# Query 12 - parcelas de maior relevância e valor significativo:
# 	 [22780, 22146, 22794, 21901, 22795, 22797, 33953, 21870, 21939, 33077, 60017, 15885, 129357]
# Query 13 - despesa sem cobertura contratual:
# 	 [18384, 17993, 18950, 19451, 17992, 18060, 34996, 18089]
# Query 14 - decreto-lei 4.657/1942:
# 	 [72433, 89820, 148892, 13141, 136866, 70638, 122137, 74048, 127373, 76604, 108627, 133580, 143862, 96574, 77584, 90030, 150929, 95575, 70807, 151614]
# Query 15 - contas e materialidade:
# 	 [80118, 23058, 23087, 104216, 83955, 19719, 61870, 118423, 69246, 68169, 14408, 32457, 19662, 19670, 33748, 31291, 19663, 19718, 23190, 35441]
# Query 16 - inexequibilidade e comprovação:
# 	 [18913, 15722, 18316, 17959, 57716, 40621, 18910, 33916, 21224, 31585, 18892, 31583, 18912, 31584, 17390, 32964, 21284, 19404, 17368, 17180]
# Query 17 - impedimento de licitar e contratar:
# 	 [14890, 34633, 16918, 16319, 98454, 68667, 34770, 34981, 38824, 34777]
# Query 18 - aditivo e obra:
# 	 [11611, 17089, 11612, 81314, 81554, 59317, 38547, 17816, 18904, 67963, 42262, 38548, 49716, 18058, 133729, 17240, 17257, 31120, 17249, 32643]
# Query 19 - fraude a licitacao:
# 	 [83961, 35195, 16879, 27842, 23158, 18256, 56336, 27959, 15244, 50130, 13678, 58215, 7618, 50555, 34990, 34971, 35192, 28166, 62197, 34630]
# Query 20 - auditoria interna:
# 	 [115, 32, 65, 50987, 55315, 133678, 28961, 85524, 80565, 12112]
# Query 21 - fracionamento de despesas:
# 	 [14829, 34918, 33891, 31640, 22972, 21265, 33033, 35011, 21279, 31621, 31620, 31638, 32884, 31641, 31639, 21277, 31428, 19086, 31618, 31622]
# Query 22 - novo e improrrogável prazo:
# 	 [22281, 32840, 13227, 41554, 27143, 46407, 15798, 26515, 26578, 69784, 126741, 135350, 109389, 71067, 57721, 8321, 135358, 124624, 76135, 19754]
# Query 23 - inidoneidade de licitante:
# 	 [2029, 75855, 35484, 135565, 34701, 35195, 44314, 44156, 35541, 27862, 12699, 40145, 71124, 8055, 34989, 56336, 28166, 82555, 34834, 34977]
# Query 24 - licitações e contratos:
# 	 [32904, 18178, 15409, 42635, 22107, 39216, 22173, 20854, 37093, 22191, 14960, 108414, 42800, 22101, 17213, 42798, 82570, 34226, 31097, 149533]
# Query 25 - exigência de atestado de capacidade:
# 	 [9884, 22154, 66344, 26341, 22150, 20596, 25593, 105994, 21924, 34316, 82565, 33938, 22149, 18291, 25230, 102918, 97634, 22159, 22792, 128212]
# Query 26 - contrato com a administração pública:
# 	 [18949, 85, 82, 14253, 31097, 33494, 34284, 39724, 39709, 82570, 10089, 11612, 51816, 73790, 34116, 137717, 54849, 91180, 149840, 42820]
# Query 27 - inexigibilidade e singularidade:
# 	 [18265, 18819, 48334, 16325, 17882, 31515, 18810, 134867, 31508, 32936, 32935, 18842, 18218, 17146, 18195, 18818, 56477, 17145, 18820, 15256]
# Query 28 - mera participação e epp:
# 	 [44132, 82277, 135549, 131055, 80814, 59938, 67158, 28166]
# Query 29 - decisão judicial:
# 	 [29646, 127, 45350, 44988, 23704, 66290, 66340, 20, 30752, 44211, 39240, 29904, 25623, 132082, 27866, 14530, 43342, 55271, 140552, 34021]
# Query 30 - fiscal de contrato:
# 	 [31097, 39724, 17213, 39709, 17220, 104561, 34121, 129445, 108431, 149840, 18386, 72433, 14611, 28923, 148773, 34216, 81742, 35041, 16991, 79286]
# Query 31 - medida cautelar:
# 	 [2078, 22230, 22252, 2807, 16966, 74258, 14869, 18393, 50721, 21240, 9589, 9690, 11638, 27031, 31376, 21228, 45273, 105746, 87939, 26453]
# Query 32 - é possível a aplicação concomitante:
# 	 [34905, 88354, 36810, 637, 16983, 57810]
# Query 33 - reajuste de contrato:
# 	 [34116, 34099, 42820, 42821, 18402, 31107, 60811, 17819, 100058, 18079, 43319, 17821, 17820, 18033, 18034, 97730, 31171, 31108, 31104, 17814]
# Query 34 - publicidade e concurso público:
# 	 [20287, 31776, 68907, 31765, 20318, 33420, 31751, 13183, 23557, 23572, 20317, 31760, 33418, 33421, 33437, 33422, 33423, 33436, 33419, 63393]
# Query 35 - falecimento e multa:
# 	 [22894, 23232, 22909, 38978, 22901, 23000, 22888, 43943, 23168, 101909, 35357, 35540, 16864, 32729, 23082, 17059, 14815, 26237, 89850, 113434]
# Query 36 - independência das instâncias:
# 	 [140, 127, 2597, 78174, 16937, 27851, 92615, 27848, 132082, 28069, 27897, 27852, 27879, 16881, 24274, 27896, 70993, 51392, 27849, 27866]
# Query 37 - planejamento estratégico:
# 	 [28964, 34326, 34343, 28974, 28909, 28975, 28962, 29382, 34261, 29395, 29532, 33957, 18326, 18895, 31370, 33931, 28896, 18137, 18128, 29383]
# Query 38 - sistema s e licitação:
# 	 [50096, 20949, 34918, 16980, 15315, 15734, 25909, 135576, 151080, 58024, 18316, 31594, 25635, 147921, 15334, 20622, 25890, 32703, 144308, 33033]
# Query 39 - citação e validade:
# 	 [12246, 12080, 26072, 16108, 23128, 25461, 84543, 26236, 132212, 88456, 135343, 106434, 41964, 75139, 32814, 17019, 26065, 32813, 26049, 52066]
# Query 40 - multa a particulares:
# 	 [19638, 61911, 90274, 78777]
# Query 41 - licitação e preço de mercado:
# 	 [32904, 18178, 15724, 58195, 18835, 40466, 34116, 13113, 52912, 16950, 31586, 35551, 34940, 31122, 21864, 62306, 50537, 18314, 75561, 35550]
# Query 42 - edital modificação:
# 	 [21058, 21162, 119633, 20556, 17169, 20835, 31599, 21057, 20855, 17036, 21070, 20597, 32980, 20856, 20537, 60017, 2957, 21198, 17267, 20610]
# Query 43 - padronização marca:
# 	 [22124, 35917, 22785, 34258, 33056, 34321, 21814, 33055, 21840]
# Query 44 - interesse recíproco:
# 	 [39056, 16246, 32696, 15067, 33818, 41478, 37170, 32672, 32671, 78586, 15071, 10016, 16121, 15370]
# Query 45 - pesquisa de preços:
# 	 [58195, 58335, 52912, 147727, 21864, 16996, 15253, 139562, 117370, 43880, 103458, 70748, 59211, 75129, 54852, 47604, 50140, 22095, 29350, 22166]
# Query 46 - planilha de custos e formação de preços:
# 	 [51881, 29394, 29356, 32965, 18323, 88847, 21259, 29371, 20483, 85586, 75210, 31108, 29393, 5709, 17262, 74717, 33026, 19430, 29349]
# Query 47 - publicidade e propaganda:
# 	 [54849, 129445, 33815, 8319, 28854, 28889, 28923, 64228, 9777, 49458, 29358, 34280, 49851, 28870, 33814, 31625, 18325, 40643, 31189, 17409]
# Query 48 - processo seletivo e sistema s:
# 	 [78023, 113690, 20257, 20307, 31722, 19602, 61098, 44837, 20308, 31740, 20258, 25410, 33122, 19617, 19601, 19572, 31724, 100415, 58133]
# Query 49 - modalidade de licitação:
# 	 [34124, 14830, 148157, 17337, 39221, 40469, 39667, 98914, 34145, 17285, 33939, 98935, 39204, 14829, 35056, 31617, 21036, 21035, 34205, 20900]
# Query 50 - antecipação de pagamento:
# 	 [44815, 103581, 33704, 18952, 47869, 17259, 7109, 18398, 17097, 17121, 17260, 32601, 150929, 32014, 14270, 55271, 29648, 29880, 29560, 29665]
# Query 51 - concessão remunerada de uso de bens públicos modalidade:
# 	 [5714, 2845]
# Query 52 - citação válida falecimento:
# 	 [41056, 38978, 17059, 150633, 21579, 139391, 72733, 36391, 106389, 149310, 85713, 70707, 142787, 15181, 89850, 113434, 15600, 40940, 43860, 13635]
# Query 53 - garantia contratual patrimônio líquido mínimo:
# 	 [48357, 31524, 17951, 17966]
# Query 54 - garantia de participação patrimônio líquido mínimo:
# 	 [26373, 48357, 22135, 21817, 22211, 22212, 25757, 19407, 21853]
# Query 55 - despesas sem cobertura contratual multa:
# 	 [19451, 17993, 17992]
# Query 56 - uso de áreas comerciais em aeroportos pregão:
# 	 [18865]
# Query 57 - cessão das áreas comerciais de centrais públicas de abastecimento de gêneros alimentícios licitação:
# 	 [5714]
# Query 58 - capacidade bens pertinentes e compatíveis com o objeto da licitação comprovação:
# 	 [71433, 123011]
# Query 59 - extrapolação dos limites para alterações consensuais qualitativas de contratos de obras e serviços:
# 	 [109695, 67390]
# Query 60 - responsabilidade do gestor sucessor omissão do antecessor:
# 	 [84720, 85445, 13770, 34672, 9989, 35435, 35258, 118076, 111444, 145500, 137127, 35430, 105418, 35428, 141944, 13233, 120403, 144943, 92531, 63595]
# Query 61 - projeto de parceria público-privada modalidade:
# 	 [44162]
# Query 62 - objeto do certame contrato social licitante:
# 	 [13694, 42817, 107361]
# Query 63 - responsabilidade gestão dos recursos Fundo Municipal de Saúde:
# 	 [75014, 17184, 13583, 109923, 83994, 43804, 4856, 57781]
# Query 64 - pesquisa de mercado orçamento fornecedores:
# 	 [21789, 31629, 22165, 22164, 21192, 20582, 22166, 21790, 22812, 22169, 22836, 19431, 142364, 47604, 151614, 22170]
# Query 65 - pesquisa de preços obrigatória em licitações:
# 	 [21864, 32467, 16869]
# Query 66 - vantajosidade adesão à ata:
# 	 [52912, 22168, 147727, 20561]
# Query 67 - compensação entre acréscimos e supressões contratos administrativos:
# 	 [10089, 17089, 11611, 11612, 104455, 18001, 17022, 17209, 49135, 18020, 17204, 17206, 18936, 17068, 134594, 17207, 109711, 67219, 18016, 17205]
# Query 68 - vedado restabelecimento item suprimido:
# 	 [104455]
# Query 69 - marca aquisição cartuchos:
# 	 [34146, 21867, 13633, 34132]
# Query 70 - SUS recursos União competência do TCU:
# 	 [40641, 9775, 106570, 82005, 29129, 31005, 25573, 13553, 18900]
# Query 71 - preços referenciais sistemas oficiais estimativa de custos:
# 	 [22165, 22164, 21264]
# Query 72 - ponderação técnica e preço:
# 	 [21229, 21159, 20969, 20970, 34126, 20506, 20870, 20971, 20869, 31601, 20871, 21072, 34233, 20585, 21207, 53641, 15740, 18915, 37613, 31689]
# Query 73 - pontuação desarrazoada licitações técnica e preço:
# 	 [133563, 33082]
# Query 74 - prorrogação de contrato administrativo término prazo de vigência:
# 	 [693, 31101, 18409, 18954]
# Query 75 - atestado de capacidade técnica serviços advocatícios conselho de fiscalização profissional:
# 	 [105994]
# Query 76 - reposição de importâncias indevidamente percebidas boa-fé servidores erro escusável por órgão/entidade:
# 	 [33621, 29832, 32034, 32024, 29664, 29854, 32402]
# Query 77 - aquisição direta risco a saúde:
# 	 [17105]
# Query 78 - pregão divulgação dos preços estimados no edital:
# 	 [71456, 17895, 17173, 19398, 14895]
# Query 79 - instrutor treinamento inexigibilidade de licitação:
# 	 [34290, 31507]
# Query 80 - reajuste de preços e repactuação:
# 	 [31108, 31104, 21100]
# Query 81 - recomposição reajuste:
# 	 [42821, 42820]
# Query 82 - retenção de pagamentos perda da regularidade fiscal:
# 	 [17220]
# Query 83 - irregulares despesas desnecessárias e anteriores à celebração do contrato:
# 	 [33083, 33080, 33081, 33937]
# Query 84 - vínculo trabalhista ou societário pré-existente competitividade das licitantes:
# 	 []
# Query 85 - técnica e preço profissionais quadro permanente:
# 	 [22781, 43098, 33083]
# Query 86 - erro material desclassificação da proposta:
# 	 [18309, 19403, 55237, 85586, 75210, 20558, 104236, 20495, 18264, 50095, 18911]
# Query 87 - vedação à inclusão documento habilitação diligência:
# 	 [122028, 21053]
# Query 88 - exigência comprovação de quantitativos mínimos características semelhantes:
# 	 [22780, 15885, 129357]
# Query 89 - extensão sanção de impedimento de licitar e contratar:
# 	 []
# Query 90 - habilitação técnico-operacional obras e serviços de engenharia:
# 	 [79794, 135758, 16911]
# Query 91 - controle adesão:
# 	 [21201, 110879]
# Query 92 - alvará de funcionamento habilitação jurídica:
# 	 [45379]
# Query 93 - acumulação de cargo secretário municipal professor:
# 	 [20797]
# Query 94 - prescrição da pretensão punitiva julgamento das contas:
# 	 [135564, 69027, 54235, 133779, 110655, 26483, 135785, 82026]
# Query 95 - Banco de Preços em Saúde referência medicamentos:
# 	 [27209, 86727, 43507, 61975, 17306, 20581, 85914, 35676]
# Query 96 - alteração contratual serviços já previstos no edital :
# 	 [72668]
# Query 97 - licitação princípio da legalidade estrita afastado:
# 	 [452]
# Query 98 - renovação de contrato serviços de natureza continuada pesquisa de preços:
# 	 [43880, 75129]
# Query 99 - contratações de software cartas de exclusividade:
# 	 [64928]
# Query 100 - assistência médica a servidores:
# 	 [17892, 18278, 31239]
# Query 101 - Qual é a modalidade de licitação adequada para a concessão remunerada de uso de bens públicos?:
# 	 [2845]
# Query 102 - A citação é considerada válida após o falecimento do responsável se a defesa já foi apresentada?:
# 	 []
# Query 103 - A prestação de garantia contratual é permitida juntamente com a exigência de patrimônio líquido mínimo?:
# 	 []
# Query 104 - A exigência de garantia de participação é permitida juntamente com a exigência de patrimônio líquido mínimo?:
# 	 []
# Query 105 - Quais são as consequências para os responsáveis que realizam despesas sem cobertura contratual?:
# 	 []
# Query 106 - O pregão é adequado para concessões de uso de áreas comerciais em aeroportos?:
# 	 []
# Query 107 - Quais normas devem ser observadas na cessão das áreas comerciais de centrais públicas de abastecimento de gêneros alimentícios?:
# 	 []
# Query 108 - É necessário exigir ao licitante comprovar que já forneceu bens pertinentes e compatíveis com o objeto da licitação?:
# 	 []
# Query 109 - É permitido a extrapolar os limites estabelecidos no art. 65, §§ 1º e 2º, da Lei 8.666/1993 para alterações consensuais qualitativas de contratos de obras e serviços?:
# 	 []
# Query 110 - Qual a responsabilidade do gestor sucessor quando o gestor antecessor omitiu o dever de prestar contas?:
# 	 []
# Query 111 - Qual é a modalidade de licitação utilizada para contratar serviços técnicos necessários à estruturação de projeto de parceria público-privada relativo a infraestrutura de rede de iluminação pública?:
# 	 []
# Query 112 - O que acontece se não houver compatibilidade entre o objeto do certame e as atividades previstas no contrato social da empresa licitante?:
# 	 []
# Query 113 - Quem é responsável pela gestão dos recursos do Fundo Municipal de Saúde?:
# 	 []
# Query 114 - É obrigatória pesquisa de mercado na elaboração do orçamento-base da licitação?:
# 	 []
# Query 115 - A pesquisa de preços correntes no mercado é obrigatória em licitações?:
# 	 []
# Query 116 - O que fazer para verificar a vantajosidade da adesão à ata?:
# 	 []
# Query 117 - É permitida a compensação entre acréscimos e supressões nos contratos administrativos?:
# 	 [17090, 17249]
# Query 118 - Quais são as condições para que o restabelecimento total ou parcial de quantitativo de item anteriormente suprimido por aditivo contratual não configure compensação vedada pela jurisprudência do TCU?:
# 	 []
# Query 119 - A Administração pode indicar preferência por marcas em licitações para aquisição de cartuchos de tinta?:
# 	 []
# Query 120 - O TCU é responsável pela fiscalização das ações e serviços de saúde pagos com recursos repassados pela União no âmbito do Sistema Único de Saúde?:
# 	 []
# Query 121 - O que deve ser feito se não for possível obter preços referenciais nos sistemas oficiais para estimativa de custos em processos licitatórios?:
# 	 []
# Query 122 - É necessária ponderação entre a pontuação técnica e a de preço em uma licitação do tipo técnica e preço?:
# 	 [20506]
# Query 123 - Como a pontuação desarrazoada pode limitar a competitividade nas licitações do tipo técnica e preço?:
# 	 []
# Query 124 - É possível prorrogar um contrato administrativo fora do término do prazo de vigência?:
# 	 []
# Query 125 - Qual é o problema na exigência de atestado de capacidade técnica para contratação de serviços advocatícios por conselho de fiscalização profissional?:
# 	 []
# Query 126 - É necessária reposição de importâncias indevidamente percebidas, de boa-fé, por servidores, em virtude de erro escusável de interpretação de lei por parte do órgão/entidade?:
# 	 []
# Query 127 - É possível aquisição direta quando a falta de produto ou serviço pode colocar em risco a saúde das pessoas?:
# 	 []
# Query 128 - É obrigatória a divulgação dos preços estimados no edital nos pregões para aquisição de medicamentos?:
# 	 []
# Query 129 - A contratação de professores, conferencistas ou instrutores para ministrar cursos de treinamento ou aperfeiçoamento de pessoal se enquadra na inexigibilidade de licitação?:
# 	 []
# Query 130 - Qual é a diferença entre reajuste de preços e repactuação?:
# 	 []
# Query 131 - É possível a aplicação da recomposição mesmo após a aplicação do reajuste previsto no contrato?:
# 	 []
# Query 132 - A retenção de pagamentos é permitida em caso de perda da regularidade fiscal?:
# 	 []
# Query 133 - Por que despesas desnecessárias e anteriores à celebração do contrato são consideradas irregulares?:
# 	 []
# Query 134 - Como o vínculo trabalhista ou societário pré-existente afeta a competitividade das licitantes no certame licitatório?:
# 	 []
# Query 135 - É permitido atribuir pontuação a uma empresa licitante nas licitações de técnica e preço com base na posse de determinados tipos de profissionais em seu quadro permanente?:
# 	 []
# Query 136 - Um erro material deve levar à desclassificação antecipada da proposta?:
# 	 []
# Query 137 - Há vedação à inclusão de novo documento destinado a atestar condição de habilitação preexistente em sede de diligência?:
# 	 [122028]
# Query 138 - A exigência de comprovação de quantitativos mínimos em obras ou serviços com características semelhantes é legal?:
# 	 []
# Query 139 - Qual a extensão da sanção de impedimento de licitar e contratar?:
# 	 []
# Query 140 - Quais documentos são exigidos para habilitação técnico-operacional em certames de obras e serviços de engenharia?:
# 	 [79794, 135758]
# Query 141 - Qual a finalidade do controle das autorizações de adesão?:
# 	 []
# Query 142 - Em que situações a apresentação do alvará de funcionamento é permitida na habilitação jurídica?:
# 	 []
# Query 143 - É permitida a acumulação do cargo de secretário municipal com o cargo de professor?:
# 	 []
# Query 144 - A prescrição da pretensão punitiva do TCU afeta o julgamento das contas?:
# 	 []
# Query 145 - O Banco de Preços em Saúde é uma referência de preços válida para a aquisição de medicamentos?:
# 	 [27209, 86727, 43507, 61975]
# Query 146 - É possível a inclusão de serviços já previstos no edital em uma alteração contratual:
# 	 []
# Query 147 - O princípio da legalidade estrita pode ser afastado em favor de outros princípios no procedimento licitatório?:
# 	 []
# Query 148 - Quais fontes devem ser prioritárias na pesquisa de preços para a renovação do contrato de serviços de natureza continuada?:
# 	 []
# Query 149 - Devem ser aceitas nas contratações de software as cartas de exclusividade emitidas pelos próprios fabricantes?:
# 	 [64928]
# Query 150 - Qual é a regra geral para a contratação de entidade para prestação de serviços de assistência médica a servidores?:
# 	 []

# %%
with open('../../data/search/juris_tcu/run_tcu_search.csv', 'w') as run:
    run.write('QUERY_ID,DOC_ID,RANK,ENGINE\n')
    for query_id, docs in result.items():
        for rank, doc in enumerate(docs):
            run.write(f'{query_id},{doc},{rank + 1},TCU_Search\n')

# %%
df_run_tcu_search = pd.read_csv('../../data/search/juris_tcu/run_tcu_search.csv')
df_run_tcu_search
# Out:
#       QUERY_ID  DOC_ID  RANK      ENGINE
# 0            1   34240     1  TCU_Search
# 1            1   20956     2  TCU_Search
# 2            1   68513     3  TCU_Search
# 3            1   51881     4  TCU_Search
# 4            1   39213     5  TCU_Search
# ...        ...     ...   ...         ...
# 1142       145   27209     1  TCU_Search
# 1143       145   86727     2  TCU_Search
# 1144       145   43507     3  TCU_Search
# 1145       145   61975     4  TCU_Search
# 1146       149   64928     1  TCU_Search
#
# [1147 rows x 4 columns]

# %%
df_run_juris_tcu = pd.read_csv('../../data/juris_tcu/qrel.csv')
df_run_juris_tcu
# Out:
#       QUERY_ID  DOC_ID  SCORE                   ENGINE  RANK
# 0            1   21064      3  (BM25|STS)+Reranker+LLM     1
# 1            1   42166      3  (BM25|STS)+Reranker+LLM     2
# 2            1   13702      3  (BM25|STS)+Reranker+LLM     3
# 3            1   20592      3  (BM25|STS)+Reranker+LLM     4
# 4            1   15740      3  (BM25|STS)+Reranker+LLM     5
# ...        ...     ...    ...                      ...   ...
# 2245       150  117370      1                 BM25+LLM   190
# 2246       150   14904      0                 BM25+LLM   185
# 2247       150   34204      0                 BM25+LLM   243
# 2248       150   70288      0                 BM25+LLM   328
# 2249       150   85641      0                 BM25+LLM   338
#
# [2250 rows x 5 columns]

# %%
df_bm25 = pd.read_csv('../../data/search/juris_tcu/run_bm25.csv')
df_bm25_reranker = pd.read_csv('../../data/search/juris_tcu/run_bm25_reranker.csv')
df_sts = pd.read_csv('../../data/search/juris_tcu/run_sts.csv')
df_sts_reranker = pd.read_csv('../../data/search/juris_tcu/run_sts_reranker.csv')
df_join_bm25_sts_reranker = pd.read_csv('../../data/search/juris_tcu/run_join_bm25_sts_reranker.csv')

# %%
df_compare_tcu_juris = df_run_tcu_search.merge(df_run_juris_tcu, how='inner', on=['QUERY_ID', 'DOC_ID'], suffixes=('_TCU', '_JURIS')).groupby('QUERY_ID').agg({'DOC_ID': 'count', 'SCORE': 'mean'})
df_compare_tcu_juris.columns = ['TCU_JURIS_DOCS', 'TCU_JURIS_AVG_SCORE']
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE
# QUERY_ID
# 1                      1             3.000000
# 2                      6             2.333333
# 3                      1             3.000000
# 4                      3             3.000000
# 5                      3             3.000000
# ...                  ...                  ...
# 122                    1             3.000000
# 137                    1             3.000000
# 140                    2             3.000000
# 145                    4             3.000000
# 149                    1             3.000000
#
# [101 rows x 2 columns]

# %%
df = df_run_tcu_search.merge(df_bm25, how='inner', on=['QUERY_ID', 'DOC_ID'], suffixes=('_TCU', '_JURIS')).groupby('QUERY_ID').agg({'DOC_ID': 'count'})
df.columns = ['BM25_DOCS']
df_compare_tcu_juris = df_compare_tcu_juris.merge(df, on='QUERY_ID', how='outer').fillna(0).sort_index()
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE  BM25_DOCS
# QUERY_ID
# 1                    1.0             3.000000         18
# 2                    6.0             2.333333         16
# 3                    1.0             3.000000         16
# 4                    3.0             3.000000         20
# 5                    3.0             3.000000         20
# ...                  ...                  ...        ...
# 122                  1.0             3.000000          1
# 137                  1.0             3.000000          1
# 140                  2.0             3.000000          2
# 145                  4.0             3.000000          4
# 149                  1.0             3.000000          1
#
# [105 rows x 3 columns]

# %%
df = df_run_tcu_search.merge(df_bm25_reranker, how='inner', on=['QUERY_ID', 'DOC_ID'], suffixes=('_TCU', '_JURIS')).groupby('QUERY_ID').agg({'DOC_ID': 'count'})
df.columns = ['BM25_RR_DOCS']
df_compare_tcu_juris = df_compare_tcu_juris.merge(df, on='QUERY_ID', how='outer').fillna(0).sort_index()
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE  BM25_DOCS  BM25_RR_DOCS
# QUERY_ID
# 1                    1.0             3.000000         18          13.0
# 2                    6.0             2.333333         16          16.0
# 3                    1.0             3.000000         16           7.0
# 4                    3.0             3.000000         20          20.0
# 5                    3.0             3.000000         20          20.0
# ...                  ...                  ...        ...           ...
# 122                  1.0             3.000000          1           1.0
# 137                  1.0             3.000000          1           1.0
# 140                  2.0             3.000000          2           2.0
# 145                  4.0             3.000000          4           4.0
# 149                  1.0             3.000000          1           1.0
#
# [105 rows x 4 columns]

# %%
df = df_run_tcu_search.merge(df_sts, how='inner', on=['QUERY_ID', 'DOC_ID'], suffixes=('_TCU', '_JURIS')).groupby('QUERY_ID').agg({'DOC_ID': 'count'})
df.columns = ['STS_DOCS']
df_compare_tcu_juris = df_compare_tcu_juris.merge(df, on='QUERY_ID', how='outer').fillna(0).sort_index()
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE  BM25_DOCS  BM25_RR_DOCS  \
# QUERY_ID
# 1                    1.0             3.000000         18          13.0
# 2                    6.0             2.333333         16          16.0
# 3                    1.0             3.000000         16           7.0
# 4                    3.0             3.000000         20          20.0
# 5                    3.0             3.000000         20          20.0
# ...                  ...                  ...        ...           ...
# 122                  1.0             3.000000          1           1.0
# 137                  1.0             3.000000          1           1.0
# 140                  2.0             3.000000          2           2.0
# 145                  4.0             3.000000          4           4.0
# 149                  1.0             3.000000          1           1.0
#
#           STS_DOCS
# QUERY_ID
# 1             16.0
# 2              5.0
# 3              6.0
# 4              7.0
# 5             12.0
# ...            ...
# 122            1.0
# 137            1.0
# 140            2.0
# 145            4.0
# 149            1.0
#
# [105 rows x 5 columns]

# %%
df = df_run_tcu_search.merge(df_sts_reranker, how='inner', on=['QUERY_ID', 'DOC_ID'], suffixes=('_TCU', '_JURIS')).groupby('QUERY_ID').agg({'DOC_ID': 'count'})
df.columns = ['STS_RR_DOCS']
df_compare_tcu_juris = df_compare_tcu_juris.merge(df, on='QUERY_ID', how='outer').fillna(0).sort_index()
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE  BM25_DOCS  BM25_RR_DOCS  \
# QUERY_ID
# 1                    1.0             3.000000         18          13.0
# 2                    6.0             2.333333         16          16.0
# 3                    1.0             3.000000         16           7.0
# 4                    3.0             3.000000         20          20.0
# 5                    3.0             3.000000         20          20.0
# ...                  ...                  ...        ...           ...
# 122                  1.0             3.000000          1           1.0
# 137                  1.0             3.000000          1           1.0
# 140                  2.0             3.000000          2           2.0
# 145                  4.0             3.000000          4           4.0
# 149                  1.0             3.000000          1           1.0
#
#           STS_DOCS  STS_RR_DOCS
# QUERY_ID
# 1             16.0         15.0
# 2              5.0          1.0
# 3              6.0          6.0
# 4              7.0          6.0
# 5             12.0         11.0
# ...            ...          ...
# 122            1.0          1.0
# 137            1.0          1.0
# 140            2.0          2.0
# 145            4.0          4.0
# 149            1.0          1.0
#
# [105 rows x 6 columns]

# %%
df = df_run_tcu_search.merge(df_join_bm25_sts_reranker, how='inner', on=['QUERY_ID', 'DOC_ID'], suffixes=('_TCU', '_JURIS')).groupby('QUERY_ID').agg({'DOC_ID': 'count'})
df.columns = ['BM25_STS_RR_DOCS']
df_compare_tcu_juris = df_compare_tcu_juris.merge(df, on='QUERY_ID', how='outer').fillna(0).sort_index()
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE  BM25_DOCS  BM25_RR_DOCS  \
# QUERY_ID
# 1                    1.0             3.000000         18          13.0
# 2                    6.0             2.333333         16          16.0
# 3                    1.0             3.000000         16           7.0
# 4                    3.0             3.000000         20          20.0
# 5                    3.0             3.000000         20          20.0
# ...                  ...                  ...        ...           ...
# 122                  1.0             3.000000          1           1.0
# 137                  1.0             3.000000          1           1.0
# 140                  2.0             3.000000          2           2.0
# 145                  4.0             3.000000          4           4.0
# 149                  1.0             3.000000          1           1.0
#
#           STS_DOCS  STS_RR_DOCS  BM25_STS_RR_DOCS
# QUERY_ID
# 1             16.0         15.0                17
# 2              5.0          1.0                16
# 3              6.0          6.0                 8
# 4              7.0          6.0                20
# 5             12.0         11.0                20
# ...            ...          ...               ...
# 122            1.0          1.0                 1
# 137            1.0          1.0                 1
# 140            2.0          2.0                 2
# 145            4.0          4.0                 4
# 149            1.0          1.0                 1
#
# [105 rows x 7 columns]

# %%
df = df_run_tcu_search.groupby('QUERY_ID').agg({'DOC_ID': 'count'})
df.columns = ['TCU_SEARCH_DOCS']
df_compare_tcu_juris = df_compare_tcu_juris.merge(df, on='QUERY_ID', how='outer').fillna(0).sort_index()
df_compare_tcu_juris
# Out:
#           TCU_JURIS_DOCS  TCU_JURIS_AVG_SCORE  BM25_DOCS  BM25_RR_DOCS  \
# QUERY_ID
# 1                    1.0             3.000000         18          13.0
# 2                    6.0             2.333333         16          16.0
# 3                    1.0             3.000000         16           7.0
# 4                    3.0             3.000000         20          20.0
# 5                    3.0             3.000000         20          20.0
# ...                  ...                  ...        ...           ...
# 122                  1.0             3.000000          1           1.0
# 137                  1.0             3.000000          1           1.0
# 140                  2.0             3.000000          2           2.0
# 145                  4.0             3.000000          4           4.0
# 149                  1.0             3.000000          1           1.0
#
#           STS_DOCS  STS_RR_DOCS  BM25_STS_RR_DOCS  TCU_SEARCH_DOCS
# QUERY_ID
# 1             16.0         15.0                17               20
# 2              5.0          1.0                16               17
# 3              6.0          6.0                 8               20
# 4              7.0          6.0                20               20
# 5             12.0         11.0                20               20
# ...            ...          ...               ...              ...
# 122            1.0          1.0                 1                1
# 137            1.0          1.0                 1                1
# 140            2.0          2.0                 2                2
# 145            4.0          4.0                 4                4
# 149            1.0          1.0                 1                1
#
# [105 rows x 8 columns]

# %%
#del df_compare_tcu_juris['TCU_JURIS_AVG_SCORE']
df_compare_tcu_juris = df_compare_tcu_juris.astype('int32')

# %%
df_compare_tcu_juris.sum().sort_values()
# Out:
# TCU_JURIS_DOCS       385
# STS_RR_DOCS          511
# STS_DOCS             627
# BM25_RR_DOCS         927
# BM25_STS_RR_DOCS     969
# BM25_DOCS           1028
# TCU_SEARCH_DOCS     1147
# dtype: int64

# %%
df_compare_tcu_juris.to_csv('../../data/search/juris_tcu/compare_search_tcu.csv')
